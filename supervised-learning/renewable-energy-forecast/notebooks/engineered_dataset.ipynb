# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os
from pathlib import Path

# Ensure the notebook can find the 'src' directory
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
# 1. Imports
from src.preprocessing.data_preprocessing import load_and_merge_data
from src.features.build_features import create_features

# 2. Ingest (The Step we just tested)
# This defines 'df' so the next line can use it
df = load_and_merge_data("Plant_1_Generation_Data.csv", "Plant_1_Weather_Sensor_Data.csv")

# 3. Engineer (The new step)
df_featured = create_features(df)

# 4. Inspect
print(f"Original shape: {df.shape}")
print(f"Featured shape: {df_featured.shape}")
print(f"Features: {df_featured.columns}")
df_featured[['DATE_TIME', 'hour_sin', 'hour_cos', 'dc_power_lag_1']].head()
# Out:
# Original shape: (68774, 11)
# Featured shape: (68771, 16)
# Features: Index(['DATE_TIME', 'PLANT_ID', 'SOURCE_KEY_x', 'DC_POWER', 'AC_POWER',
#        'DAILY_YIELD', 'TOTAL_YIELD', 'SOURCE_KEY_y', 'AMBIENT_TEMPERATURE',
#        'MODULE_TEMPERATURE', 'IRRADIATION', 'hour_sin', 'hour_cos',
#        'dc_power_lag_1', 'irrad_lag_1', 'irrad_rolling_avg_1h'],
#       dtype='object')
# /Users/davideferreri/Documents/GitHub/ML-and-AI/supervised-learning/renewable-energy-forecast/src/preprocessing/data_preprocessing.py:25: UserWarning: Parsing dates in %d-%m-%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   gen_df['DATE_TIME'] = pd.to_datetime(gen_df['DATE_TIME'], dayfirst=False)
#    DATE_TIME  hour_sin  hour_cos  dc_power_lag_1
# 3 2020-05-15       0.0       1.0             0.0
# 4 2020-05-15       0.0       1.0             0.0
# 5 2020-05-15       0.0       1.0             0.0
# 6 2020-05-15       0.0       1.0             0.0
# 7 2020-05-15       0.0       1.0             0.0
